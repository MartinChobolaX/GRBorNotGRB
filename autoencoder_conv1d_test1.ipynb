# %%
#importing libs
import numpy as np
import matplotlib.pyplot as plt
import glob
from data_gen import *
from predict_info import *

import datetime

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Reshape, Dense, Flatten, Input, Conv1D, Conv1DTranspose, MaxPooling1D, UpSampling1D, BatchNormalization, ZeroPadding1D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard, ModelCheckpoint, ReduceLROnPlateau

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import auc, roc_curve, confusion_matrix


from tensorflow.config.experimental import list_physical_devices, set_virtual_device_configuration, VirtualDeviceConfiguration

gpus = list_physical_devices('GPU')
set_virtual_device_configuration(gpus[0], [VirtualDeviceConfiguration(memory_limit=6000)])#
print(len(gpus), "Physical GPUs")
# Out:
# 1 Physical GPUs

# %%
df = pd.read_csv("Data/scaled_xyzlog_without_GRBs.csv", index_col=0) # data (hopefuly without grbs)
df
# Out:
# /home/mchobola/anaconda3/envs/envi/lib/python3.9/site-packages/numpy/lib/arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                time         x         y         z   log_cps
# 0        481.489854  0.351577 -0.470408 -0.809389  1.981139
# 1        481.489901  0.402253 -0.651949 -0.642771  1.985651
# 2        481.489947  0.402425 -0.804490 -0.436865  1.984527
# 3        481.489993  0.359273 -0.910516 -0.204654  2.024280
# 4        481.490039  0.284601 -0.957816  0.039879  1.973128
# ...             ...       ...       ...       ...       ...
# 2054802  719.491781 -0.080000  0.068985  0.994405  2.120574
# 2054803  719.491793 -0.125928  0.111252  0.985782  2.130334
# 2054804  719.491804 -0.170043  0.154518  0.973247  2.152288
# 2054805  719.491816 -0.212694  0.197985  0.956851  2.176091
# 2054806  719.491827 -0.253000  0.242204  0.936658  2.146128
#
# [2044439 rows x 5 columns]

# %%
rollWindowSize = 4
rollWindow = df['log_cps'].rolling(rollWindowSize)
rollAvr = rollWindow.mean()
plt.plot(df['log_cps'][rollWindowSize:1000+rollWindowSize])
plt.plot(rollAvr[0:1000])
df['log_cps'] = rollAvr

# %%
df
# Out:
#                time         x         y         z   log_cps
# 0        481.489854  0.351577 -0.470408 -0.809389       NaN
# 1        481.489901  0.402253 -0.651949 -0.642771       NaN
# 2        481.489947  0.402425 -0.804490 -0.436865       NaN
# 3        481.489993  0.359273 -0.910516 -0.204654  1.993899
# 4        481.490039  0.284601 -0.957816  0.039879  1.991897
# ...             ...       ...       ...       ...       ...
# 2054802  719.491781 -0.080000  0.068985  0.994405  2.154808
# 2054803  719.491793 -0.125928  0.111252  0.985782  2.150859
# 2054804  719.491804 -0.170043  0.154518  0.973247  2.153178
# 2054805  719.491816 -0.212694  0.197985  0.956851  2.144822
# 2054806  719.491827 -0.253000  0.242204  0.936658  2.151210
#
# [2044439 rows x 5 columns]

# %%
df = df.drop(df.index[:rollWindowSize-1])
df
# Out:
#                time         x         y         z   log_cps
# 3        481.489993  0.359273 -0.910516 -0.204654  1.993899
# 4        481.490039  0.284601 -0.957816  0.039879  1.991897
# 5        481.490086  0.191439 -0.940405  0.281052  1.977839
# 6        481.490132  0.098804 -0.856678  0.506301  1.970869
# 7        481.490178  0.021979 -0.712759  0.701065  1.950611
# ...             ...       ...       ...       ...       ...
# 2054802  719.491781 -0.080000  0.068985  0.994405  2.154808
# 2054803  719.491793 -0.125928  0.111252  0.985782  2.150859
# 2054804  719.491804 -0.170043  0.154518  0.973247  2.153178
# 2054805  719.491816 -0.212694  0.197985  0.956851  2.144822
# 2054806  719.491827 -0.253000  0.242204  0.936658  2.151210
#
# [2044436 rows x 5 columns]

# %%
def df_to_X(df, windowSize=512):
    dfNumpy = df.to_numpy()
    X = []
    for i in range(len(dfNumpy)-windowSize):
        if abs(dfNumpy[i+windowSize][0] - (windowSize*(dfNumpy[i-1][0]-dfNumpy[i][0])+dfNumpy[i][0])) < 1:
            X.append(dfNumpy[i:i+windowSize,-1])
    return np.array(X, dtype=np.float32)

# %%
X = df_to_X(df,windowSize=512)
X = tf.random.shuffle(X, seed=420)
# Out:
# 2023-05-02 13:56:08.776738: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-02 13:56:08.778021: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-05-02 13:56:08.778194: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-02 13:56:08.778516: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2080 SUPER computeCapability: 7.5
# coreClock: 1.83GHz coreCount: 48 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 462.00GiB/s
# 2023-05-02 13:56:08.778558: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-05-02 13:56:08.778579: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2023-05-02 13:56:08.778594: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2023-05-02 13:56:08.778609: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-05-02 13:56:08.778624: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-05-02 13:56:08.778638: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2023-05-02 13:56:08.778653: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2023-05-02 13:56:08.778668: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2023-05-02 13:56:08.778724: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-02 13:56:08.779041: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-02 13:56:08.779312: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2023-05-02 13:56:08.780174: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-05-02 13:56:10.811892: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-05-02 13:56:10.811928: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2023-05-02 13:56:10.811938: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2023-05-02 13:56:10.813225: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-02 13:56:10.813952: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-02 13:56:10.814602: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-02 13:56:10.815132: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6000 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 SUPER, pci bus id: 0000:01:00.0, compute capability: 7.5)
# 2023-05-02 13:56:10.819424: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 4141000704 exceeds 10% of free system memory.
# 2023-05-02 13:56:12.676935: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 4141000704 exceeds 10% of free system memory.

# %%
splitIndex = int(len(X) * 0.8)
X_train, y_train, X_test, y_test = X[0:splitIndex],X[0:splitIndex],X[splitIndex:],X[splitIndex:]

# %%
np.shape(X_train[0])
# Out:
# TensorShape([512])

# %% [markdown]
# # Autoencoder

# %%
# Define model
def create_autoencoder():
    # Encoder
    inputs = Input(shape=(512,1))
    x = Conv1D(filters=64, kernel_size=3, padding='same', activation='relu')(inputs)
    x = MaxPooling1D(pool_size=2, padding='same')(x)
    x = Conv1D(filters=8, kernel_size=3, padding='same', activation='relu')(x)
    x = MaxPooling1D(pool_size=2, padding='same')(x)
    x = Flatten()(x)
    encoded = Dense(8,activation='relu')(x)
    
  
    # Decoder
    x = Dense(8,activation='relu')(encoded)
    x = Reshape((8,1))(x)
    x = Conv1D(filters=8, kernel_size=3, padding='same', activation='relu')(x)
    x = UpSampling1D(size=2)(x)
    x = Conv1D(filters=64, kernel_size=3, padding='same', activation='sigmoid')(x)
    x = Flatten()(x)
    x = Dense(512,activation='relu')(x)
    decoded = Reshape((512,1))(x)
  
    # Define autoencoder
    autoencoder = Model(inputs, decoded)
    autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
    return autoencoder


autoencoder = create_autoencoder()
autoencoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 512, 1)]          0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 512, 64)           256
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 256, 64)           0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 256, 8)            1544
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 128, 8)            0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 8200
# _________________________________________________________________
# dense_4 (Dense)              (None, 8)                 72
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 8, 1)              0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 8, 8)              32
# _________________________________________________________________
# up_sampling1d_1 (UpSampling1 (None, 16, 8)             0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 16, 64)            1600
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               524800
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 512, 1)            0
# =================================================================
# Total params: 536,504
# Trainable params: 536,504
# Non-trainable params: 0
# _________________________________________________________________

# %%
fileName = '{}-{}-{}-{}'.format(datetime.datetime.today().month,
          datetime.datetime.today().day,
          datetime.datetime.today().hour,
          datetime.datetime.today().minute)
callback_conv = [EarlyStopping(monitor='val_loss', patience=4),
                 ModelCheckpoint("models/autoConv/{}.h5".format(fileName), 
                                 monitor='val_loss',
                                 verbose=1,
                                 save_best_only=True, 
                                 mode='min'),
                ReduceLROnPlateau(monitor='val_loss',factor=0.2,patience=2,verbose=True,min_lr=0.0001),
                TensorBoard(log_dir = "./Tensor_logs/auto/{}".format(fileName), update_freq="epoch")]


history = autoencoder.fit(X_train, y_train,
          validation_data = (X_test, y_test),
          epochs=100, callbacks=[callback_conv],
                         shuffle=True)
# Out:
# 2023-05-02 13:56:15.327595: I tensorflow/core/profiler/lib/profiler_session.cc:136] Profiler session initializing.
# 2023-05-02 13:56:15.327613: I tensorflow/core/profiler/lib/profiler_session.cc:155] Profiler session started.
# 2023-05-02 13:56:15.329378: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1365] Profiler found 1 GPUs
# 2023-05-02 13:56:15.344187: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcupti.so.10.1
# 2023-05-02 13:56:15.445610: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1415] function cupti_interface_->Subscribe( &subscriber_, (CUpti_CallbackFunc)ApiCallback, this)failed with error CUPTI_ERROR_INSUFFICIENT_PRIVILEGES
# 2023-05-02 13:56:15.447046: I tensorflow/core/profiler/lib/profiler_session.cc:172] Profiler session tear down.
# 2023-05-02 13:56:15.504693: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 3312799744 exceeds 10% of free system memory.
# 2023-05-02 13:56:16.980054: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 3312799744 exceeds 10% of free system memory.
# 2023-05-02 13:56:18.481117: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2023-05-02 13:56:18.506421: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3600000000 Hz
# Epoch 1/100
# 2023-05-02 13:56:19.006291: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2023-05-02 13:56:19.592846: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
#    44/50550 [..............................] - ETA: 3:26 - loss: 4.3349
# 2023-05-02 13:56:22.234282: I tensorflow/core/profiler/lib/profiler_session.cc:136] Profiler session initializing.
# 2023-05-02 13:56:22.234314: I tensorflow/core/profiler/lib/profiler_session.cc:155] Profiler session started.
# 2023-05-02 13:56:22.235159: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1415] function cupti_interface_->Subscribe( &subscriber_, (CUpti_CallbackFunc)ApiCallback, this)failed with error CUPTI_ERROR_INSUFFICIENT_PRIVILEGES
# 2023-05-02 13:56:22.242409: I tensorflow/core/profiler/lib/profiler_session.cc:71] Profiler session collecting data.
# 2023-05-02 13:56:22.244101: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:228]  GpuTracer has collected 0 callback api events and 0 activity events.
# 2023-05-02 13:56:22.246219: I tensorflow/core/profiler/lib/profiler_session.cc:172] Profiler session tear down.
# 2023-05-02 13:56:22.253456: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: ./Tensor_logs/auto/5-2-13-56/train/plugins/profile/2023_05_02_13_56_22
# 2023-05-02 13:56:22.255382: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for trace.json.gz to ./Tensor_logs/auto/5-2-13-56/train/plugins/profile/2023_05_02_13_56_22/cthulhu.trace.json.gz
# 2023-05-02 13:56:22.280477: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: ./Tensor_logs/auto/5-2-13-56/train/plugins/profile/2023_05_02_13_56_22
# 2023-05-02 13:56:22.283401: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for memory_profile.json.gz to ./Tensor_logs/auto/5-2-13-56/train/plugins/profile/2023_05_02_13_56_22/cthulhu.memory_profile.json.gz
# 2023-05-02 13:56:22.283658: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: ./Tensor_logs/auto/5-2-13-56/train/plugins/profile/2023_05_02_13_56_22Dumped tool data for xplane.pb to ./Tensor_logs/auto/5-2-13-56/train/plugins/profile/2023_05_02_13_56_22/cthulhu.xplane.pb
# Dumped tool data for overview_page.pb to ./Tensor_logs/auto/5-2-13-56/train/plugins/profile/2023_05_02_13_56_22/cthulhu.overview_page.pb
# Dumped tool data for input_pipeline.pb to ./Tensor_logs/auto/5-2-13-56/train/plugins/profile/2023_05_02_13_56_22/cthulhu.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to ./Tensor_logs/auto/5-2-13-56/train/plugins/profile/2023_05_02_13_56_22/cthulhu.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to ./Tensor_logs/auto/5-2-13-56/train/plugins/profile/2023_05_02_13_56_22/cthulhu.kernel_stats.pb
# 50550/50550 [==============================] - 131s 3ms/step - loss: 2.0256 - val_loss: 0.3961
#
# Epoch 00001: val_loss improved from inf to 0.39605, saving model to models/autoConv/5-2-13-56.h5
# Epoch 2/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.3183 - val_loss: 0.2472
#
# Epoch 00002: val_loss improved from 0.39605 to 0.24722, saving model to models/autoConv/5-2-13-56.h5
# Epoch 3/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.2220 - val_loss: 0.1809
#
# Epoch 00003: val_loss improved from 0.24722 to 0.18090, saving model to models/autoConv/5-2-13-56.h5
# Epoch 4/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.1813 - val_loss: 0.1552
#
# Epoch 00004: val_loss improved from 0.18090 to 0.15518, saving model to models/autoConv/5-2-13-56.h5
# Epoch 5/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.1536 - val_loss: 0.1521
#
# Epoch 00005: val_loss improved from 0.15518 to 0.15214, saving model to models/autoConv/5-2-13-56.h5
# Epoch 6/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.1456 - val_loss: 0.1227
#
# Epoch 00006: val_loss improved from 0.15214 to 0.12265, saving model to models/autoConv/5-2-13-56.h5
# Epoch 7/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.1223 - val_loss: 0.1247
#
# Epoch 00007: val_loss did not improve from 0.12265
# Epoch 8/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.1201 - val_loss: 0.1027
#
# Epoch 00008: val_loss improved from 0.12265 to 0.10268, saving model to models/autoConv/5-2-13-56.h5
# Epoch 9/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.1044 - val_loss: 0.1094
#
# Epoch 00009: val_loss did not improve from 0.10268
# Epoch 10/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.1057 - val_loss: 0.0993
#
# Epoch 00010: val_loss improved from 0.10268 to 0.09932, saving model to models/autoConv/5-2-13-56.h5
# Epoch 11/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0991 - val_loss: 0.0753
#
# Epoch 00011: val_loss improved from 0.09932 to 0.07534, saving model to models/autoConv/5-2-13-56.h5
# Epoch 12/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0725 - val_loss: 0.0667
#
# Epoch 00012: val_loss improved from 0.07534 to 0.06675, saving model to models/autoConv/5-2-13-56.h5
# Epoch 13/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0667 - val_loss: 0.0645
#
# Epoch 00013: val_loss improved from 0.06675 to 0.06453, saving model to models/autoConv/5-2-13-56.h5
# Epoch 14/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0716 - val_loss: 0.0668
#
# Epoch 00014: val_loss did not improve from 0.06453
# Epoch 15/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0659 - val_loss: 0.0648
#
# Epoch 00015: val_loss did not improve from 0.06453
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 16/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0631 - val_loss: 0.0624
#
# Epoch 00016: val_loss improved from 0.06453 to 0.06241, saving model to models/autoConv/5-2-13-56.h5
# Epoch 17/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0628 - val_loss: 0.0626
#
# Epoch 00017: val_loss did not improve from 0.06241
# Epoch 18/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0624 - val_loss: 0.0620
#
# Epoch 00018: val_loss improved from 0.06241 to 0.06203, saving model to models/autoConv/5-2-13-56.h5
# Epoch 19/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0621 - val_loss: 0.0617
#
# Epoch 00019: val_loss improved from 0.06203 to 0.06167, saving model to models/autoConv/5-2-13-56.h5
# Epoch 20/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0619 - val_loss: 0.0616
#
# Epoch 00020: val_loss improved from 0.06167 to 0.06163, saving model to models/autoConv/5-2-13-56.h5
# Epoch 21/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0617 - val_loss: 0.0616
#
# Epoch 00021: val_loss improved from 0.06163 to 0.06157, saving model to models/autoConv/5-2-13-56.h5
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 22/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0614 - val_loss: 0.0611
#
# Epoch 00022: val_loss improved from 0.06157 to 0.06106, saving model to models/autoConv/5-2-13-56.h5
# Epoch 23/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0613 - val_loss: 0.0610
#
# Epoch 00023: val_loss improved from 0.06106 to 0.06103, saving model to models/autoConv/5-2-13-56.h5
# Epoch 24/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0611 - val_loss: 0.0609
#
# Epoch 00024: val_loss improved from 0.06103 to 0.06087, saving model to models/autoConv/5-2-13-56.h5
# Epoch 25/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0611 - val_loss: 0.0609
#
# Epoch 00025: val_loss did not improve from 0.06087
# Epoch 26/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0609 - val_loss: 0.0609
#
# Epoch 00026: val_loss improved from 0.06087 to 0.06086, saving model to models/autoConv/5-2-13-56.h5
# Epoch 27/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0609 - val_loss: 0.0607
#
# Epoch 00027: val_loss improved from 0.06086 to 0.06070, saving model to models/autoConv/5-2-13-56.h5
# Epoch 28/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0608 - val_loss: 0.0606
#
# Epoch 00028: val_loss improved from 0.06070 to 0.06057, saving model to models/autoConv/5-2-13-56.h5
# Epoch 29/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0607 - val_loss: 0.0607
#
# Epoch 00029: val_loss did not improve from 0.06057
# Epoch 30/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0608 - val_loss: 0.0606
#
# Epoch 00030: val_loss did not improve from 0.06057
# Epoch 31/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0606 - val_loss: 0.0604
#
# Epoch 00031: val_loss improved from 0.06057 to 0.06043, saving model to models/autoConv/5-2-13-56.h5
# Epoch 32/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0606 - val_loss: 0.0606
#
# Epoch 00032: val_loss did not improve from 0.06043
# Epoch 33/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0605 - val_loss: 0.0603
#
# Epoch 00033: val_loss improved from 0.06043 to 0.06032, saving model to models/autoConv/5-2-13-56.h5
# Epoch 34/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0603 - val_loss: 0.0602
#
# Epoch 00034: val_loss improved from 0.06032 to 0.06021, saving model to models/autoConv/5-2-13-56.h5
# Epoch 35/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0603 - val_loss: 0.0602
#
# Epoch 00035: val_loss improved from 0.06021 to 0.06021, saving model to models/autoConv/5-2-13-56.h5
# Epoch 36/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0602 - val_loss: 0.0601
#
# Epoch 00036: val_loss improved from 0.06021 to 0.06014, saving model to models/autoConv/5-2-13-56.h5
# Epoch 37/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0601 - val_loss: 0.0602
#
# Epoch 00037: val_loss did not improve from 0.06014
# Epoch 38/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0601 - val_loss: 0.0601
#
# Epoch 00038: val_loss improved from 0.06014 to 0.06005, saving model to models/autoConv/5-2-13-56.h5
# Epoch 39/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0600 - val_loss: 0.0600
#
# Epoch 00039: val_loss improved from 0.06005 to 0.06000, saving model to models/autoConv/5-2-13-56.h5
# Epoch 40/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0599 - val_loss: 0.0600
#
# Epoch 00040: val_loss improved from 0.06000 to 0.05995, saving model to models/autoConv/5-2-13-56.h5
# Epoch 41/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0600 - val_loss: 0.0599
#
# Epoch 00041: val_loss improved from 0.05995 to 0.05993, saving model to models/autoConv/5-2-13-56.h5
# Epoch 42/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0598 - val_loss: 0.0598
#
# Epoch 00042: val_loss improved from 0.05993 to 0.05977, saving model to models/autoConv/5-2-13-56.h5
# Epoch 43/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0600 - val_loss: 0.0597
#
# Epoch 00043: val_loss improved from 0.05977 to 0.05969, saving model to models/autoConv/5-2-13-56.h5
# Epoch 44/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0597 - val_loss: 0.0596
#
# Epoch 00044: val_loss improved from 0.05969 to 0.05963, saving model to models/autoConv/5-2-13-56.h5
# Epoch 45/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0598 - val_loss: 0.0596
#
# Epoch 00045: val_loss improved from 0.05963 to 0.05962, saving model to models/autoConv/5-2-13-56.h5
# Epoch 46/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0597 - val_loss: 0.0596
#
# Epoch 00046: val_loss improved from 0.05962 to 0.05958, saving model to models/autoConv/5-2-13-56.h5
# Epoch 47/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0595 - val_loss: 0.0596
#
# Epoch 00047: val_loss did not improve from 0.05958
# Epoch 48/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0595 - val_loss: 0.0595
#
# Epoch 00048: val_loss improved from 0.05958 to 0.05954, saving model to models/autoConv/5-2-13-56.h5
# Epoch 49/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0594 - val_loss: 0.0598
#
# Epoch 00049: val_loss did not improve from 0.05954
# Epoch 50/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0596 - val_loss: 0.0596
#
# Epoch 00050: val_loss did not improve from 0.05954
# Epoch 51/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0593 - val_loss: 0.0592
#
# Epoch 00051: val_loss improved from 0.05954 to 0.05922, saving model to models/autoConv/5-2-13-56.h5
# Epoch 52/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0595 - val_loss: 0.0593
#
# Epoch 00052: val_loss did not improve from 0.05922
# Epoch 53/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0593 - val_loss: 0.0591
#
# Epoch 00053: val_loss improved from 0.05922 to 0.05912, saving model to models/autoConv/5-2-13-56.h5
# Epoch 54/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0594 - val_loss: 0.0593
#
# Epoch 00054: val_loss did not improve from 0.05912
# Epoch 55/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0592 - val_loss: 0.0595
#
# Epoch 00055: val_loss did not improve from 0.05912
# Epoch 56/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0592 - val_loss: 0.0591
#
# Epoch 00056: val_loss improved from 0.05912 to 0.05912, saving model to models/autoConv/5-2-13-56.h5
# Epoch 57/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0593 - val_loss: 0.0592
#
# Epoch 00057: val_loss did not improve from 0.05912
# Epoch 58/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0591 - val_loss: 0.0592
#
# Epoch 00058: val_loss did not improve from 0.05912
# Epoch 59/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0590 - val_loss: 0.0589
#
# Epoch 00059: val_loss improved from 0.05912 to 0.05889, saving model to models/autoConv/5-2-13-56.h5
# Epoch 60/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0590 - val_loss: 0.0589
#
# Epoch 00060: val_loss improved from 0.05889 to 0.05887, saving model to models/autoConv/5-2-13-56.h5
# Epoch 61/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0589 - val_loss: 0.0594
#
# Epoch 00061: val_loss did not improve from 0.05887
# Epoch 62/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0590 - val_loss: 0.0588
#
# Epoch 00062: val_loss improved from 0.05887 to 0.05880, saving model to models/autoConv/5-2-13-56.h5
# Epoch 63/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0588 - val_loss: 0.0588
#
# Epoch 00063: val_loss improved from 0.05880 to 0.05880, saving model to models/autoConv/5-2-13-56.h5
# Epoch 64/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0589 - val_loss: 0.0587
#
# Epoch 00064: val_loss improved from 0.05880 to 0.05874, saving model to models/autoConv/5-2-13-56.h5
# Epoch 65/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0588 - val_loss: 0.0588
#
# Epoch 00065: val_loss did not improve from 0.05874
# Epoch 66/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0589 - val_loss: 0.0587
#
# Epoch 00066: val_loss did not improve from 0.05874
# Epoch 67/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0586 - val_loss: 0.0586
#
# Epoch 00067: val_loss improved from 0.05874 to 0.05862, saving model to models/autoConv/5-2-13-56.h5
# Epoch 68/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0589 - val_loss: 0.0586
#
# Epoch 00068: val_loss did not improve from 0.05862
# Epoch 69/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0587 - val_loss: 0.0587
#
# Epoch 00069: val_loss did not improve from 0.05862
# Epoch 70/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0587 - val_loss: 0.0585
#
# Epoch 00070: val_loss improved from 0.05862 to 0.05854, saving model to models/autoConv/5-2-13-56.h5
# Epoch 71/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0586 - val_loss: 0.0588
#
# Epoch 00071: val_loss did not improve from 0.05854
# Epoch 72/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0586 - val_loss: 0.0584
#
# Epoch 00072: val_loss improved from 0.05854 to 0.05845, saving model to models/autoConv/5-2-13-56.h5
# Epoch 73/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0586 - val_loss: 0.0584
#
# Epoch 00073: val_loss improved from 0.05845 to 0.05844, saving model to models/autoConv/5-2-13-56.h5
# Epoch 74/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0584 - val_loss: 0.0587
#
# Epoch 00074: val_loss did not improve from 0.05844
# Epoch 75/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0584 - val_loss: 0.0585
#
# Epoch 00075: val_loss did not improve from 0.05844
# Epoch 76/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0584 - val_loss: 0.0583
#
# Epoch 00076: val_loss improved from 0.05844 to 0.05833, saving model to models/autoConv/5-2-13-56.h5
# Epoch 77/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0584 - val_loss: 0.0586
#
# Epoch 00077: val_loss did not improve from 0.05833
# Epoch 78/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0583 - val_loss: 0.0583
#
# Epoch 00078: val_loss improved from 0.05833 to 0.05825, saving model to models/autoConv/5-2-13-56.h5
# Epoch 79/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0583 - val_loss: 0.0584
#
# Epoch 00079: val_loss did not improve from 0.05825
# Epoch 80/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0583 - val_loss: 0.0582
#
# Epoch 00080: val_loss improved from 0.05825 to 0.05823, saving model to models/autoConv/5-2-13-56.h5
# Epoch 81/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0582 - val_loss: 0.0584
#
# Epoch 00081: val_loss did not improve from 0.05823
# Epoch 82/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0584 - val_loss: 0.0585
#
# Epoch 00082: val_loss did not improve from 0.05823
# Epoch 83/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0583 - val_loss: 0.0583
#
# Epoch 00083: val_loss did not improve from 0.05823
# Epoch 84/100
# 50550/50550 [==============================] - 113s 2ms/step - loss: 0.0583 - val_loss: 0.0584
#
# Epoch 00084: val_loss did not improve from 0.05823

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']


plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.yscale("log")
plt.show()

# %%
X_pred = autoencoder.predict(X_test)
x = np.arange(len(X_test[0]))

# %%
fig, axs = plt.subplots(5,5,figsize=(16,16))

for i in range(5):
    for j in range(5):
        ind = np.random.randint(len(y_test))
        axs[i,j].scatter(x,X_test[ind],marker='.')
        axs[i,j].scatter(x,X_pred[ind],color="red",marker='.');

# %%
fig, axs = plt.subplots(5,5,figsize=(16,16))

for i in range(5):
    for j in range(5):
        ind = np.random.randint(len(y_test))
        axs[i,j].scatter(x,10**(X_test[ind]),marker='.')
        axs[i,j].scatter(x,10**(X_pred[ind]),color="red",marker='.');

# %%
def isModelGood(model,windowSize):
    grbs = glob.glob("Data/scaled_xyzlog_512-128_64/*.csv")
    for n , grb in enumerate(grbs):
        df = pd.read_csv(grb, index_col=0)
        num_df = df.to_numpy()
        df = df.drop(['0'],axis=1)
        X0 = tf.convert_to_tensor(df.to_numpy()[-windowSize:,-1])
        plt.plot(X0)
        print(np.shape(X0))
        print(len(X0))
        pred, true = [],[]
        pred.append(model.predict(X0))
        true.append(X0)
    return true, pred
true, pred = isModelGood(autoencoder,512)
# Out:
# (512,)
# 512
# WARNING:tensorflow:Model was constructed with shape (None, 512, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 512, 1), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (32, 1, 1).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 15
#      13         true.append(X0)
#      14     return true, pred
# ---> 15 true, pred = isModelGood(autoencoder,512)
#
# Cell In[38], line 12, in isModelGood(model, windowSize)
#      10     print(len(X0))
#      11     pred, true = [],[]
# ---> 12     pred.append(model.predict(X0))
#      13     true.append(X0)
#      14 return true, pred
#
# File ~/anaconda3/envs/envi/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:1629, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1627 for step in data_handler.steps():
#    1628   callbacks.on_predict_batch_begin(step)
# -> 1629   tmp_batch_outputs = self.predict_function(iterator)
#    1630   if data_handler.should_sync:
#    1631     context.async_wait()
#
# File ~/anaconda3/envs/envi/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:828, in Function.__call__(self, *args, **kwds)
#     826 tracing_count = self.experimental_get_tracing_count()
#     827 with trace.Trace(self._name) as tm:
# --> 828   result = self._call(*args, **kwds)
#     829   compiler = "xla" if self._experimental_compile else "nonXla"
#     830   new_tracing_count = self.experimental_get_tracing_count()
#
# File ~/anaconda3/envs/envi/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:862, in Function._call(self, *args, **kwds)
#     859 self._lock.release()
#     860 # In this case we have not created variables on the first call. So we can
#     861 # run the first trace but we should fail if variables are created.
# --> 862 results = self._stateful_fn(*args, **kwds)
#     863 if self._created_variables:
#     864   raise ValueError("Creating variables on a non-first call to a function"
#     865                    " decorated with tf.function.")
#
# File ~/anaconda3/envs/envi/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2941, in Function.__call__(self, *args, **kwargs)
#    2938 """Calls a graph function specialized to the inputs."""
#    2939 with self._lock:
#    2940   (graph_function,
# -> 2941    filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942 return graph_function._call_flat(
#    2943     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/anaconda3/envs/envi/lib/python3.9/site-packages/tensorflow/python/eager/function.py:3357, in Function._maybe_define_function(self, args, kwargs)
#    3347 with ag_ctx.ControlStatusCtx(
#    3348     status=ag_status, options=self._autograph_options):
#    3349
#    (...)
#    3352   # and 2. there's no provided input signature
#    3353   # and 3. there's been a cache miss for this calling context
#    3354   if (self._experimental_relax_shapes and
#    3355       self.input_signature is None and
#    3356       call_context_key in self._function_cache.missed):
# -> 3357     return self._define_function_with_shape_relaxation(
#    3358         args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3360   self._function_cache.missed.add(call_context_key)
#    3361   graph_function = self._create_graph_function(args, kwargs)
#
# File ~/anaconda3/envs/envi/lib/python3.9/site-packages/tensorflow/python/eager/function.py:3279, in Function._define_function_with_shape_relaxation(self, args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3272   (relaxed_arg_specs, relaxed_kwarg_specs) = nest.pack_sequence_as(
#    3273       (args, kwargs), relaxed_arg_specs, expand_composites=False)
#    3274   (args, kwargs) = nest.pack_sequence_as(
#    3275       (relaxed_arg_specs, relaxed_kwarg_specs),
#    3276       flat_args,
#    3277       expand_composites=True)
# -> 3279 graph_function = self._create_graph_function(
#    3280     args, kwargs, override_flat_arg_shapes=relaxed_arg_shapes)
#    3281 self._function_cache.arg_relaxed[rank_only_cache_key] = graph_function
#    3283 return (graph_function, [
#    3284     t for t in nest.flatten((args, kwargs), expand_composites=True)
#    3285     if isinstance(t, (ops.Tensor,
#    3286                       resource_variable_ops.BaseResourceVariable))
#    3287 ])
#
# File ~/anaconda3/envs/envi/lib/python3.9/site-packages/tensorflow/python/eager/function.py:3196, in Function._create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3191 missing_arg_names = [
#    3192     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    3193 ]
#    3194 arg_names = base_arg_names + missing_arg_names
#    3195 graph_function = ConcreteFunction(
# -> 3196     func_graph_module.func_graph_from_py_func(
#    3197         self._name,
#    3198         self._python_function,
#    3199         args,
#    3200         kwargs,
#    3201         self.input_signature,
#    3202         autograph=self._autograph,
#    3203         autograph_options=self._autograph_options,
#    3204         arg_names=arg_names,
#    3205         override_flat_arg_shapes=override_flat_arg_shapes,
#    3206         capture_by_value=self._capture_by_value),
#    3207     self._function_attributes,
#    3208     function_spec=self.function_spec,
#    3209     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    3210     # scope. This is not the default behavior since it gets used in some
#    3211     # places (like Keras) where the FuncGraph lives longer than the
#    3212     # ConcreteFunction.
#    3213     shared_func_graph=False)
#    3214 return graph_function
#
# File ~/anaconda3/envs/envi/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py:990, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     987 else:
#     988   _, original_func = tf_decorator.unwrap(python_func)
# --> 990 func_outputs = python_func(*func_args, **func_kwargs)
#     992 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#     993 # TensorArrays and `None`s.
#     994 func_outputs = nest.map_structure(convert, func_outputs,
#     995                                   expand_composites=True)
#
# File ~/anaconda3/envs/envi/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:634, in Function._defun_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     632     xla_context.Exit()
#     633 else:
# --> 634   out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     635 return out
#
# File ~/anaconda3/envs/envi/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py:977, in func_graph_from_py_func.<locals>.wrapper(*args, **kwargs)
#     975 except Exception as e:  # pylint:disable=broad-except
#     976   if hasattr(e, "ag_error_metadata"):
# --> 977     raise e.ag_error_metadata.to_exception(e)
#     978   else:
#     979     raise
#
# ValueError: in user code:
#
#     /home/mchobola/anaconda3/envs/envi/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:1478 predict_function  *
#         return step_function(self, iterator)
#     /home/mchobola/anaconda3/envs/envi/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:1468 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /home/mchobola/anaconda3/envs/envi/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /home/mchobola/anaconda3/envs/envi/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /home/mchobola/anaconda3/envs/envi/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /home/mchobola/anaconda3/envs/envi/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:1461 run_step  **
#         outputs = model.predict_step(data)
#     /home/mchobola/anaconda3/envs/envi/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:1434 predict_step
#         return self(x, training=False)
#     /home/mchobola/anaconda3/envs/envi/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py:1012 __call__
#         outputs = call_fn(inputs, *args, **kwargs)
#     /home/mchobola/anaconda3/envs/envi/lib/python3.9/site-packages/tensorflow/python/keras/engine/functional.py:424 call
#         return self._run_internal_graph(
#     /home/mchobola/anaconda3/envs/envi/lib/python3.9/site-packages/tensorflow/python/keras/engine/functional.py:560 _run_internal_graph
#         outputs = node.layer(*args, **kwargs)
#     /home/mchobola/anaconda3/envs/envi/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /home/mchobola/anaconda3/envs/envi/lib/python3.9/site-packages/tensorflow/python/keras/engine/input_spec.py:255 assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer dense is incompatible with the layer: expected axis -1 of input shape to have value 1024 but received input with shape (32, 8)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 true, pred = isModelGood(autoencoder,512)
#
# Cell In[24], line 9, in isModelGood(model, windowSize)
#       7 num_df = df.to_numpy()
#       8 df = df.drop(['0'],axis=1)
# ----> 9 X0 = df[-windowSize:,-1].to_numpy()
#      10 pred, true = [],[]
#      11 pred.append(model.predict(X0))
#
# File ~/anaconda3/envs/envi/lib/python3.9/site-packages/pandas/core/frame.py:3458, in DataFrame.__getitem__(self, key)
#    3456 if self.columns.nlevels > 1:
#    3457     return self._getitem_multilevel(key)
# -> 3458 indexer = self.columns.get_loc(key)
#    3459 if is_integer(indexer):
#    3460     indexer = [indexer]
#
# File ~/anaconda3/envs/envi/lib/python3.9/site-packages/pandas/core/indexes/base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3359 casted_key = self._maybe_cast_indexer(key)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#    3363     raise KeyError(key) from err
#
# File ~/anaconda3/envs/envi/lib/python3.9/site-packages/pandas/_libs/index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/envi/lib/python3.9/site-packages/pandas/_libs/index.pyx:82, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(-512, None, None), -1)' is an invalid key

# %%
#autoencoder.save("autoencoder_conv1d")
